# %% [markdown]
# Now we've had knowledge of coalescent theory and known some useful conclusions, for example, expected time for two sampled alleles to trace back to their common ancestor when the population size is given. We can utilize those to 'devise' some genomic methods.
# D-statistic was first proposed in Green et al 2010 Science to test whether the Null hypothesis holds for there popualtions and outgroup population: alleles in an archaic population that is diverged earlier, match P1 and P2 equally often.
# The alternative hypothesis is that under the phylogeny relationships as Null Hypothesis indicated,the P3 exchange genes with P1 or P2 after these two populations diverged else.
# The basic version of D comparing four chromosomes one each from P1,P2,P3 and O separately.
# It requires two copies of both alleles (A/B) existing in the four samples and P3 is derived allale: i.e. only count ABBA and BABA, if the Null hypothesis hlods, i.e. the phylogeny is consistent with Null hypothesis:
# ![image.png](attachment:image.png)
# Only two configurations, one each from II and III, can produce ABBA or BABA patterns. Specifically, only one mutation occurred on the third branch during the history shown as the bottom panel of figure above. Then the possiblities that B occured in the sampled chromosomes was related to the branch length and the mutation rate. The branch length can be derived through conclusions of coalescent theory that we have had.
# The core principle of D-statistic is that it can be mathematically proven that only the Null hypothetical model will give E(D) to 0, whereas under an Alternative phylogeny with gene flow, the E(D) deviates from 0:
# There are three scenarios, models graphically illustrated below, in which gene flow from P3 to either P1 or P2 with fraction f of P3 ancestry can create the two geneologies, giving rise to ABBA or BABA.(assuming instantaneous unidirectional admixture model first, the conclusion holds for ongoing migration between P3 and P2 or P1 and the bidirectional exchange gene flow are equivalent)
# ![image-2.png](attachment:image-2.png)
# In the first scenario that the P2 lineage traces its ancestry through the modern human side of the phylogny(probability 1-f), and between tH and tN, the P1 and P2 lineages do not coalescent.
# So the expected branch length that the P1/P2 coalescent to P3 as illustrated in N123 of the leftmost demogrophic graph is N123, and detailed the all possibilities genealogies of the three lieanages on the top. Only the first two possible genealogical topologies can produce ABBA or BABA with mutation occured at the positions indicated as red spark. So the possibility that randomly chosen site will have either patterns is(only ABBA pattern can occur in this scenario):
# P(ABBA)=the probability of the approprate topology · the expected branch length · mutation rate
# = the probability of the P1 and P2 lineages do not coalescent during tH to tN · the propotion for the ancetry from only P1 and P2 not from geneflow · probability the two genealogies occured during time back before tN and mutation occuring on the branch 3
# = $(1 - 2N_{12})^{t_N - t_H} \cdot (1 - f) \cdot 2/3\cdot N_{123}\cdot \mu $
#
# ,Where the probability of the P1 and P2 lineages do not coalescent during tH to tN is the $G_{2,2}$ in [Coalescent Theory Outline](note07.ipynb) and the expected length of branch 3 is $E[T_i]$.
#
# The remaining two scenarios can be derived in an analogous manner.
# Sum the three scenarios for ABBA and BABA patterns, the overall expectation for D:
# E(D)=$\frac{P(ABBA)-P(BABA)}{P(ABBA)+P(BABA)}$ =...
# =$
# \frac{3f[t_N-t_{GF}+2(N_{123}-N_3)(1-(1-\frac{1}{2N_3})^{t_N-t_{GF}})]}{3f[t_N-t_{GF}+2(N_{123}-N_3)(1-(1-\frac{1}{2N_3})^{t_N-t_{GF}})]+4N_{123}(1-f)(1-\frac{1}{2N_{12}})^{t_N-t_H}+4N_{123}f(1-\frac{1}{2N_3})^{t_N-t_{GF}}}
# $
# If there is no gene flow,f=0, then E(D)=0. i.e. the observation D(P1,P2,P3,O)=$\frac{ \sum_{i}^{n}{(C_{ABBA}(i) - C_{BABA}(i))} }{\sum_{i}^{n}{(C_{ABBA}(i) + C_{BABA}(i))} }$ should not deviates from 0 when Null hypothesis holds. If $N_3=N_{12}=N_{123}$ this formula is the formula (5) in Durand et al. 2011 MBE as $N_{123}-N_3=0$.
# For population sequencing data, using frequency to represent the probability that a random chosen chromosome from a given population is derived allele. i.e. $p_i=E(C_{ABBA or BABA}(i))$
# D(P1,P2,P3,O)=$\frac{}{}$
# 在计算D-statistic时，由于连锁不平衡，二项检验D是否偏离0就不适用了，因此用block jackknife procedure to obtain the standard deviation.
#
# Practically in ADMIXTOOLS, D is calculated through:
#
#
#
# In fact, the D-statisitc is from a four population test in Reich et al 2019 nature. And together with other F-statistic are rooted in the idea that compute Fst along branches. The idea of counting the ABBA,BABA and BBAA patterns can also be used to evaluate the phylogeny relationships or branching order of the four species/populations by test whether it is consistent with patterns of the SNP data, and a lot of researches have leveraged this.
#
# For example, [my previous work](https://doi.org/10.1101/2020.02.03.933069) has researched the origin of domestic ducks fully utilized F3-statistic and observation on the four population patterns. this work push the divergence time between domestic lineage and mallard,spot-billed backward to farther long time,even before the human civilizations.
# ![image-3.png](attachment:image-3.png)
#
# Although my limited expression ability didn't grant me courage and power to dedicate to make a successfully publication, some of my findings have nevertheless been reported in some other latter publications now. But I believe that, in a good-faith pursuit of truth regarding domestication, speciation or some other interests like flight ability evolution, the appearance of similar findings in subsequent work should not preclude the formal preprint to publication of earlier original research as the reviewer did(https://github.com/ruiliuacd/duckdomestic1/blob/main/manuscript/point%20to%20point%20file%20GBIO.pdf). After all I have devoted 20 years of my life into this paper since 2011, while for much of the time after 2015 I primarily involved in communication and coordination work under supervision. Furthermore, I find the analyses in the current publications could be improved when fully considering my paper not just attract by my findings as I unofficially illustrated everwhere. For example, althoug <Nine high-quality Anas genomes provide insights into Anas evolution and domestication> did a lot of excellent works, but l'd like to remind that:
# their Fst between MA and SB used only two individuals are not representative, while my paper have made an more comphensive analysis using 14 vs 13 individuals.
# Their phylogenetic tree for nine Anas species are based on whole genome alignment, whereas I just a little bit caution about this methods while I also did similar results based on chr1
# ![image-4.png](attachment:image-4.png)
# subsequenced analysis used  D-statistic (|Z|) to infer introgression, but this ABBA-BABA pattern based methods can have a little bit extension to infer the phylogenetic relationship from the population prespective as describe above. In the section of "absence of introgression evidence of mallard and spot-billed further support their shallow divergence" in my paper, we have shown that AABB pattern have overwhelming significantly higher number than other two patterns as Fig. S31. It means ....  .
# This is interesting that when using multi-samples based on population genetics would give the different tree toplogy from the one based on single genome aligenment. I'd like to investigated the assemble technical detail to question why this different especially we find that short reads assemble may produce different sequence from reality when we doing the lucifery validation experiment we found. should caution does the genome comparasions of the genomes of MA, SB and PK used are result from similar assemble technique and pipeline. the technique issues may cause the PK cluster with the MA. further more this supporting topology is only a little more frequencies than the two altanative one, It may represent a rapid radiation especially when win size decreased. and when win size was 500bp for Z chromosome genes, the cluster order changed.
# Further more D-statistic are not supposed to indicate ILS and the coalescent time of segments. and It infer the introgression should have a certein phylogentic tree in advance whereas taking granted that the tree topology infered from whole genome alignment and 4d-sites(by the way 4d-sites is the conding sequence tree, what the meaning for itself is consistent with itself?) was correct, maybe not proper. Logically, why not use D/ABBA-BABA method suite to infer the relationships first as my paper and many other paper did.
#
#
# All my illustration in my github repos are unofficial discussion and are not publication media. I could modifed or delete if someone care about.
