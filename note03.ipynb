# %% [markdown]
# **4. Application of Dimensionality Reduction Techniques and expansion in GWAS and co-evolution**
# The inter-relationships between different genomic regions/locis or between the gut-microbiome and the host genetic adaptation are lack of proper and prevalent approaches to discover. Such relationships may appear as co-evolution, genetic incompatibilities or epistatic effects and should be very prevalent in life system. It may behivor in different level such as cooperative functions of different parts of system (e.g. endocrine system), gene-retrotransposons interactions, cooperation of transcription factor/enhancer or speciation process.
